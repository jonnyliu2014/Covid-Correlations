# %%
# load pre-processed data for a specific date covid + death + diabetes + obesity + physical_inactivity
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats

# %%
# df = pd.read_csv('data/cc-data-2020-12-31.csv')
df = pd.read_csv('data/cc-data-2021-02-28.csv')
df.corr(method = 'pearson')
# Out:
#                                 County FIPS  Covid Cases  Covid Deaths  \
# County FIPS                        1.000000    -0.055414     -0.043600
# Covid Cases                       -0.055414     1.000000      0.910802
# Covid Deaths                      -0.043600     0.910802      1.000000
# County Population                 -0.060008     0.928787      0.753921
# Covid Case Percentage             -0.049287     0.108996      0.155488
# Covid Death Percentage            -0.027316     0.065417      0.192946
# Obesity Percentage                -0.028474     0.033730      0.014755
# Diabetes Percentage               -0.085904     0.038681      0.030128
# Physical Inactivity Percentage    -0.152735     0.014688      0.019938
#
#                                 County Population  Covid Case Percentage  \
# County FIPS                             -0.060008              -0.049287
# Covid Cases                              0.928787               0.108996
# ...

# %%
df_wa = df[(df['State'] == "Washington")]
df_wa.corr(method = 'pearson')
# Out:
#                                 County FIPS  Covid Cases  Covid Deaths  \
# County FIPS                        1.000000     0.113111      0.123912
# Covid Cases                        0.113111     1.000000      0.995533
# Covid Deaths                       0.123912     0.995533      1.000000
# County Population                  0.079187     0.958838      0.965444
# Covid Case Percentage             -0.136304     0.175712      0.133648
# Covid Death Percentage            -0.165484     0.200129      0.186322
# Obesity Percentage                -0.146663    -0.042073     -0.070246
# Diabetes Percentage               -0.047938     0.174375      0.146433
# Physical Inactivity Percentage    -0.140532    -0.191909     -0.194605
#
#                                 County Population  Covid Case Percentage  \
# County FIPS                              0.079187              -0.136304
# Covid Cases                              0.958838               0.175712
# ...

# %%
df_sub = df[(df['State'] == "California") & (df['County Population'] > 500000)]
print(df_sub['County FIPS'].size)
df_sub.corr(method = 'pearson')
# Out:
# 16
#                                 County FIPS  Covid Cases  Covid Deaths  \
# County FIPS                        1.000000    -0.171858     -0.179005
# Covid Cases                       -0.171858     1.000000      0.992024
# Covid Deaths                      -0.179005     0.992024      1.000000
# County Population                 -0.197048     0.982900      0.980668
# Covid Case Percentage              0.060420     0.473947      0.404893
# Covid Death Percentage             0.074761     0.663662      0.656837
# Obesity Percentage                -0.117859    -0.076665     -0.101565
# Diabetes Percentage                0.028248     0.204795      0.148747
# Physical Inactivity Percentage    -0.002912    -0.090733     -0.112411
#
#                                 County Population  Covid Case Percentage  \
# County FIPS                             -0.197048               0.060420
# Covid Cases                              0.982900               0.473947
# ...

# %%
# sns.regplot(x=df_sub["Physical Inactivity Percentage"], y=df_sub["Covid Case Percentage"])
sns.regplot(x=df_sub["Diabetes Percentage"], y=df_sub["Covid Case Percentage"])
# r, p = stats.pearsonr(df_sub['Covid Case Percentage'], df_sub['Diabetes Percentage'])
r, p = stats.pearsonr(df_sub['Covid Death Percentage'], df_sub['Diabetes Percentage'])
print("correlation:", r, "p-value:", p)
# Out:
# correlation: -0.5700606677308259 p-value: 0.23753506796938123

# %%
df_sub = df[(df['State'] == "New York") & (df['County Population'] > 500000)]
print(df_sub['County FIPS'].size)
df_sub
# df_sub.corr(method = 'pearson')
r, p = stats.pearsonr(df_sub['Covid Case Percentage'], df_sub['Diabetes Percentage'])
print("correlation:", r, "p-value:", p)
# Out:
# 6
# correlation: -0.6226160528248494 p-value: 0.18675471044443237

# %%
df_wa = df[(df['State'] == "Texas")]
df_wa.corr(method = 'pearson')
# Out:
#                                 County FIPS  Covid Cases  Covid Deaths  \
# County FIPS                        1.000000    -0.051575     -0.057297
# Covid Cases                       -0.051575     1.000000      0.961475
# Covid Deaths                      -0.057297     0.961475      1.000000
# County Population                 -0.054515     0.976228      0.940623
# Covid Case Percentage              0.045439     0.033539      0.045666
# Covid Death Percentage             0.017726    -0.191731     -0.133436
# Obesity Percentage                -0.015052     0.401630      0.460235
# Diabetes Percentage                0.007249     0.344304      0.422874
# Physical Inactivity Percentage     0.008281     0.332113      0.394892
#
#                                 County Population  Covid Case Percentage  \
# County FIPS                             -0.054515               0.045439
# Covid Cases                              0.976228               0.033539
# ...

# %%
df_wa = df[(df['State'] == "Florida")]
df_wa.corr(method = 'pearson')
# Out:
#                                 County FIPS  Covid Cases  Covid Deaths  \
# County FIPS                        1.000000     0.036581      0.066933
# Covid Cases                        0.036581     1.000000      0.976049
# Covid Deaths                       0.066933     0.976049      1.000000
# County Population                  0.056703     0.946821      0.948656
# Covid Case Percentage             -0.059659     0.151959      0.067547
# Covid Death Percentage             0.002225    -0.139819     -0.098688
# Obesity Percentage                -0.054179    -0.349667     -0.378526
# Diabetes Percentage               -0.170173    -0.304145     -0.332207
# Physical Inactivity Percentage    -0.202529    -0.281288     -0.307305
#
#                                 County Population  Covid Case Percentage  \
# County FIPS                              0.056703              -0.059659
# Covid Cases                              0.946821               0.151959
# ...

# %%
df['State'].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
# whole country
df_sub = df

r, p = stats.pearsonr(df_sub['Covid Case Percentage'], df_sub['Physical Inactivity Percentage'])
print("covid correlation:", r, "p-value:", p)
r, p = stats.pearsonr(df_sub['Covid Death Percentage'], df_sub['Physical Inactivity Percentage'])
print("covid correlation:", r, "p-value:", p)
# Out:
# covid correlation: 0.16007247322366017 p-value: 2.00608804553259e-19
# covid correlation: 0.06760459791058387 p-value: 0.00015292916623332436

# %%
#from termcolor import colored

for s in df['State'].unique():
    df_sub = df[(df['State'] == s)]  # & (df['County Population'] > 500000)]
    #df_sub = df[(df['State'] == s) & (df['County Population'] > 50000)]

    print("== state:", s, df_sub['County FIPS'].size)
    if df_sub['County FIPS'].size > 5:
        r, p = stats.pearsonr(df_sub['Covid Case Percentage'], df_sub['Physical Inactivity Percentage'])
        if p < 0.001:
            print("correlation:", r, "p-value:", p)
            print("^^^^^^^^^^^^^^^^^")
        #else:
            #print("correlation:", r, "p-value:", p)
# Out:
# == state: Alabama 67
# == state: Alaska 24
# == state: Arizona 15
# == state: Arkansas 75
# == state: California 58
# correlation: 0.6423635930315745 p-value: 5.4644087291562783e-08
# ^^^^^^^^^^^^^^^^^
# == state: Colorado 64
# == state: Connecticut 8
# == state: Delaware 3
# == state: District of Columbia 1
# == state: Florida 67
# correlation: 0.4389538522977475 p-value: 0.00020251227870884083
# ^^^^^^^^^^^^^^^^^
# == state: Georgia 159
# == state: Hawaii 5
# == state: Idaho 44
# == state: Illinois 102
# == state: Indiana 92
# == state: Iowa 99
# == state: Kansas 105
# == state: Kentucky 120
# == state: Louisiana 64
# == state: Maine 16
# == state: Maryland 24
# == state: Massachusetts 14
# == state: Michigan 83
# == state: Minnesota 87
# == state: Mississippi 82
# == state: Missouri 115
# == state: Montana 56
# correlation: 0.5375132217545362 p-value: 1.939720829378906e-05
# ^^^^^^^^^^^^^^^^^
# == state: Nebraska 93
# ...

# %%
#from termcolor import colored

for s in df['State'].unique():
    df_sub = df[(df['State'] == s)]  # & (df['County Population'] > 500000)]
    #df_sub = df[(df['State'] == s) & (df['County Population'] > 50000)]

    print("== state:", s, df_sub['County FIPS'].size)
    if df_sub['County FIPS'].size > 5:
        r, p = stats.pearsonr(df_sub['Covid Case Percentage'], df_sub['Obesity Percentage'])
        if p < 0.001:
            print("correlation:", r, "p-value:", p)
            print("^^^^^^^^^^^^^^^^^")
        #else:
            #print("correlation:", r, "p-value:", p)
# Out:
# == state: Alabama 67
# == state: Alaska 24
# == state: Arizona 15
# == state: Arkansas 75
# == state: California 58
# correlation: 0.5564411486001266 p-value: 5.74730276639908e-06
# ^^^^^^^^^^^^^^^^^
# == state: Colorado 64
# == state: Connecticut 8
# == state: Delaware 3
# == state: District of Columbia 1
# == state: Florida 67
# == state: Georgia 159
# == state: Hawaii 5
# == state: Idaho 44
# == state: Illinois 102
# == state: Indiana 92
# == state: Iowa 99
# == state: Kansas 105
# == state: Kentucky 120
# == state: Louisiana 64
# == state: Maine 16
# == state: Maryland 24
# == state: Massachusetts 14
# == state: Michigan 83
# == state: Minnesota 87
# == state: Mississippi 82
# == state: Missouri 115
# correlation: 0.31034416966381934 p-value: 0.0007369253292925688
# ^^^^^^^^^^^^^^^^^
# == state: Montana 56
# correlation: 0.45876897896590974 p-value: 0.0003764121861886198
# ^^^^^^^^^^^^^^^^^
# == state: Nebraska 93
# correlation: 0.6188276822083023 p-value: 3.8201130160222313e-11
# ...

# %%
#from termcolor import colored

for s in df['State'].unique():
    df_sub = df[(df['State'] == s)]  # & (df['County Population'] > 500000)]
    #df_sub = df[(df['State'] == s) & (df['County Population'] > 50000)]

    print("== state:", s, df_sub['County FIPS'].size)
    if df_sub['County FIPS'].size > 5:
        r, p = stats.pearsonr(df_sub['Covid Case Percentage'], df_sub['Diabetes Percentage'])
        if p < 0.001:
            print("correlation:", r, "p-value:", p)
            print("^^^^^^^^^^^^^^^^^")
        #else:
            #print("correlation:", r, "p-value:", p)
# Out:
# == state: Alabama 67
# == state: Alaska 24
# == state: Arizona 15
# == state: Arkansas 75
# == state: California 58
# correlation: 0.6199333308570326 p-value: 2.109939144992408e-07
# ^^^^^^^^^^^^^^^^^
# == state: Colorado 64
# == state: Connecticut 8
# == state: Delaware 3
# == state: District of Columbia 1
# == state: Florida 67
# == state: Georgia 159
# == state: Hawaii 5
# == state: Idaho 44
# == state: Illinois 102
# == state: Indiana 92
# == state: Iowa 99
# == state: Kansas 105
# == state: Kentucky 120
# == state: Louisiana 64
# == state: Maine 16
# == state: Maryland 24
# == state: Massachusetts 14
# == state: Michigan 83
# == state: Minnesota 87
# == state: Mississippi 82
# == state: Missouri 115
# == state: Montana 56
# == state: Nebraska 93
# correlation: 0.41400024368137 p-value: 3.7048134697286645e-05
# ^^^^^^^^^^^^^^^^^
# == state: Nevada 17
# == state: New Hampshire 10
# == state: New Jersey 21
# == state: New Mexico 32
# ...

# %%
print("Covid Death % - Physical Inactivity %")
for s in df['State'].unique():
    df_sub = df[(df['State'] == s)]  # & (df['County Population'] > 500000)]
    #df_sub = df[(df['State'] == s) & (df['County Population'] > 50000)]

    print("== state:", s, df_sub['County FIPS'].size)
    if df_sub['County FIPS'].size > 5:
        r, p = stats.pearsonr(df_sub['Covid Death Percentage'], df_sub['Physical Inactivity Percentage'])
        if p < 0.005:
            print("correlation:", r, "p-value:", p)
            print("^^^^^^^^^^^^^^^^^")
# Out:
# Covid Death % - Physical Inactivity %
# == state: Alabama 67
# == state: Alaska 24
# correlation: 0.5917910002697643 p-value: 0.002317684225515221
# ^^^^^^^^^^^^^^^^^
# == state: Arizona 15
# == state: Arkansas 75
# == state: California 58
# correlation: 0.5409060111256941 p-value: 1.1673301771076726e-05
# ^^^^^^^^^^^^^^^^^
# == state: Colorado 64
# correlation: 0.5203184544162203 p-value: 1.0484011167986705e-05
# ^^^^^^^^^^^^^^^^^
# == state: Connecticut 8
# == state: Delaware 3
# == state: District of Columbia 1
# == state: Florida 67
# correlation: 0.42018605996614655 p-value: 0.0004001000148444767
# ^^^^^^^^^^^^^^^^^
# == state: Georgia 159
# == state: Hawaii 5
# == state: Idaho 44
# == state: Illinois 102
# == state: Indiana 92
# == state: Iowa 99
# == state: Kansas 105
# == state: Kentucky 120
# == state: Louisiana 64
# == state: Maine 16
# == state: Maryland 24
# == state: Massachusetts 14
# correlation: 0.7414993824177123 p-value: 0.002402860374783406
# ^^^^^^^^^^^^^^^^^
# ...

# %%
print("Covid Death % - Obesity %")
for s in df['State'].unique():
    df_sub = df[(df['State'] == s)]  # & (df['County Population'] > 500000)]
    #df_sub = df[(df['State'] == s) & (df['County Population'] > 50000)]

    print("== state:", s, df_sub['County FIPS'].size)
    if df_sub['County FIPS'].size > 5:
        r, p = stats.pearsonr(df_sub['Covid Death Percentage'], df_sub['Obesity Percentage'])
        if p < 0.001:
            print("correlation:", r, "p-value:", p)
            print("^^^^^^^^^^^^^^^^^")
# Out:
# Covid Death % - Obesity %
# == state: Alabama 67
# == state: Alaska 24
# == state: Arizona 15
# == state: Arkansas 75
# == state: California 58
# correlation: 0.5939677552696556 p-value: 8.880675845961828e-07
# ^^^^^^^^^^^^^^^^^
# == state: Colorado 64
# correlation: 0.5484329448026932 p-value: 2.7123164847674897e-06
# ^^^^^^^^^^^^^^^^^
# == state: Connecticut 8
# == state: Delaware 3
# == state: District of Columbia 1
# == state: Florida 67
# == state: Georgia 159
# correlation: -0.2773164614050474 p-value: 0.0004017898352287155
# ^^^^^^^^^^^^^^^^^
# == state: Hawaii 5
# == state: Idaho 44
# correlation: 0.4841745672137028 p-value: 0.0008681365546555928
# ^^^^^^^^^^^^^^^^^
# == state: Illinois 102
# == state: Indiana 92
# == state: Iowa 99
# == state: Kansas 105
# == state: Kentucky 120
# == state: Louisiana 64
# == state: Maine 16
# == state: Maryland 24
# == state: Massachusetts 14
# == state: Michigan 83
# == state: Minnesota 87
# == state: Mississippi 82
# ...

# %%
print("Covid Death % - Diabetes %")
for s in df['State'].unique():
    df_sub = df[(df['State'] == s)]  # & (df['County Population'] > 500000)]
    #df_sub = df[(df['State'] == s) & (df['County Population'] > 50000)]

    print("== state:", s, df_sub['County FIPS'].size)
    if df_sub['County FIPS'].size > 5:
        r, p = stats.pearsonr(df_sub['Covid Death Percentage'], df_sub['Diabetes Percentage'])
        if p < 0.001:
            print("correlation:", r, "p-value:", p)
            print("^^^^^^^^^^^^^^^^^")
# Out:
# Covid Death % - Diabetes %
# == state: Alabama 67
# == state: Alaska 24
# == state: Arizona 15
# == state: Arkansas 75
# == state: California 58
# correlation: 0.5507010463626225 p-value: 7.4983071032953925e-06
# ^^^^^^^^^^^^^^^^^
# == state: Colorado 64
# correlation: 0.4218774503060255 p-value: 0.0005164089053106101
# ^^^^^^^^^^^^^^^^^
# == state: Connecticut 8
# == state: Delaware 3
# == state: District of Columbia 1
# == state: Florida 67
# == state: Georgia 159
# == state: Hawaii 5
# == state: Idaho 44
# correlation: 0.4850835092539636 p-value: 0.0008460421500272093
# ^^^^^^^^^^^^^^^^^
# == state: Illinois 102
# == state: Indiana 92
# == state: Iowa 99
# == state: Kansas 105
# == state: Kentucky 120
# == state: Louisiana 64
# == state: Maine 16
# == state: Maryland 24
# == state: Massachusetts 14
# == state: Michigan 83
# == state: Minnesota 87
# == state: Mississippi 82
# == state: Missouri 115
# == state: Montana 56
# == state: Nebraska 93
# == state: Nevada 17
# ...
